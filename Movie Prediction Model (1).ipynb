# %% [markdown]
# ## TASK-2 :- MOVIE RATING PREDICTION MODEL WITH PYTHON
# ## AUTHOR :- NISHITA SHARMA
# ## BATCH :- JUNE
# ## DOMAIN :- DATA SCIENCE
# ## AIM :- TO BUILD A MODEL THAT PREDICTS THE RATING OF A MOVIE BASED ON FEATUTES LIKE GENRE,DIRECTOR, AND ACTORS

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load the Dataset

# %%
data= pd.read_csv('movies.csv')

# %%
data
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi) -2019.0  109 min
# 3                                 #Yaaram -2019.0  110 min
# 5                    ...Aur Pyaar Ho Gaya -1997.0  147 min
# 6                               ...Yahaan -2005.0  142 min
# 8                      ?: A Question Mark -2012.0   82 min
# ...                                   ...     ...      ...
# 15501                     Zulm Ki Hukumat -1992.0      NaN
# 15503                     Zulm Ki Zanjeer -1989.0  125 min
# 15504                 Zulm Ko Jala Doonga -1988.0      NaN
# 15505                               Zulmi -1999.0  129 min
# 15508                        Zulm-O-Sitam -1998.0  130 min
#
#                            Genre  Rating  Votes           Director  \
# 1                          Drama     7.0      8      Gaurav Bakshi
# 3                Comedy, Romance     4.4     35         Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6            Drama, Romance, War     7.4   1086     Shoojit Sircar
# 8      Horror, Mystery, Thriller     5.6    326      Allyson Patel
# ...                          ...     ...    ...                ...
# 15501       Action, Crime, Drama     5.3    135  Bharat Rangachary
# 15503       Action, Crime, Drama     5.8     44    S.P. Muthuraman
# 15504                     Action     4.6     11      Mahendra Shah
# 15505              Action, Drama     4.5    655         Kuku Kohli
# 15508              Action, Drama     6.2     20       K.C. Bokadia
#
#                 Actor 1                 Actor 2          Actor 3
# 1          Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 3               Prateik              Ishita Raj  Siddhant Kapoor
# 5            Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6       Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 8             Yash Dave          Muntazir Ahmad     Kiran Bhatia
# ...                 ...                     ...              ...
# 15501        Dharmendra     Moushumi Chatterjee          Govinda
# 15503       Chiranjeevi              Jayamalini      Rajinikanth
# 15504  Naseeruddin Shah           Sumeet Saigal    Suparna Anand
# 15505      Akshay Kumar          Twinkle Khanna      Aruna Irani
# 15508        Dharmendra              Jaya Prada      Arjun Sarja
#
# [7558 rows x 10 columns]

# %%
data.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                         #Homecoming -2021.0   90 min   Drama, Musical
# 3                             #Yaaram -2019.0  110 min  Comedy, Romance
# 4                   ...And Once Again -2010.0  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#                Year       Rating
# count  14981.000000  7919.000000
# mean   -1987.012215     5.841621
# std       25.416689     1.381777
# min    -2022.000000     1.100000
# 25%    -2009.000000     4.900000
# 50%    -1991.000000     6.000000
# 75%    -1968.000000     6.800000
# max    -1913.000000    10.000000

# %%
# checking for null values
data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %% [markdown]
# ## Handling Missing values

# %%
data.dropna(subset=["Rating"],inplace=True)

# %%
data.isnull().sum()
# Out:
# Name           0
# Year           0
# Duration    1899
# Genre          0
# Rating         0
# Votes          0
# Director       0
# Actor 1        0
# Actor 2        0
# Actor 3        0
# dtype: int64

# %%
data.dropna(subset=['Actor 1','Actor 2','Actor 3','Director','Genre'],inplace=True)

# %%
data.isnull().sum()
# Out:
# Name           0
# Year           0
# Duration    1899
# Genre          0
# Rating         0
# Votes          0
# Director       0
# Actor 1        0
# Actor 2        0
# Actor 3        0
# dtype: int64

# %%
data.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min
# 3                             #Yaaram -2019.0  110 min
# 5                ...Aur Pyaar Ho Gaya -1997.0  147 min
# 6                           ...Yahaan -2005.0  142 min
# 8                  ?: A Question Mark -2012.0   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4   1086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# 6          Minissha Lamba   Yashpal Sharma
# 8          Muntazir Ahmad     Kiran Bhatia

# %%
data['Duration']=data['Duration'].str.strip('min')

# %%
data['Duration'].fillna(data['Duration'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7558 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7558 non-null   object
#  1   Year      7558 non-null   float64
#  2   Duration  7558 non-null   object
#  3   Genre     7558 non-null   object
#  4   Rating    7558 non-null   float64
#  5   Votes     7558 non-null   int32
#  6   Director  7558 non-null   object
#  7   Actor 1   7558 non-null   object
#  8   Actor 2   7558 non-null   object
#  9   Actor 3   7558 non-null   object
# dtypes: float64(2), int32(1), object(7)
# memory usage: 620.0+ KB

# %%
data.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi) -2019.0     109
# 3                             #Yaaram -2019.0     110
# 5                ...Aur Pyaar Ho Gaya -1997.0     147
# 6                           ...Yahaan -2005.0     142
# 8                  ?: A Question Mark -2012.0      82
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4   1086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# 6          Minissha Lamba   Yashpal Sharma
# 8          Muntazir Ahmad     Kiran Bhatia

# %% [markdown]
# ## Finding Top 10 Movies

# %%
top_movie = data.loc[data['Rating'].sort_values(ascending=False)[:10].index]
top_movie
# Out:
#                       Name  Year Duration                   Genre  Rating  \
# 8339       Love Qubool Hai -2020      94           Drama, Romance    10.0
# 5410            Half Songs -2021      79           Music, Romance     9.7
# 2563                 Breed -2020    135.0                   Drama     9.6
# 14222  The Reluctant Crime -2020     113                    Drama     9.4
# 5077          Gho Gho Rani -2019     105         History, Romance     9.4
# 6852                  June -2021      93                    Drama     9.4
# 12673   Secrets of Sinauli -2021      56     Documentary, History     9.3
# 5125           God of gods -2019      90              Documentary     9.3
# 8344          Love Sorries -2021     101   Comedy, Drama, Romance     9.3
# 1314          Ashok Vatika -2018      97                    Drama     9.3
#
#        Votes         Director            Actor 1          Actor 2  \
# 8339       5  Saif Ali Sayeed          Ahaan Jha   Mahesh Narayan
# 5410       7      Sriram Raja       Raj Banerjee  Emon Chatterjee
# 2563      48      Bobby Kumar        Bobby Kumar           Ashfaq
# 14222     16    Arvind Pratap    Dharmendra Ahir   Awanish Kotnal
# 5077      47     Munni Pankaj  Nishi Neha Mishra     Pankaj Kamal
# 6852      18   Suhrud Godbole     Vaibhav Khisti   Nilesh Divekar
# 12673   1373   Raghav Jairath     Manoj Bajpayee       R.S. Bhist
# 5125      46     Venkatesh Bk  Tejaswini Manogna    Triyug Mantri
# 8344      79     Gautam Joshi   Prashant Chaubey  Puneet Chouksey
# 1314       7    Rahul Mallick         Kunj Anand   Sanjay Bishnoi
#
#                    Actor 3
# 8339   Rajasree Rajakumari
# 5410     Purshottam Mulani
# 2563        Fasih Choudhry
# 14222         Rakhi Mansha
# 5077           Akash Kumar
# 6852        Jitendra Joshi
# 12673           K.N. Dixit
# 5125       Raj Singh Verma
# 8344         Amitabh Gupta
# 1314          Paras Zutshi

# %% [markdown]
# ## Data Exploration and Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(data=top_movie,x="Year",hue="Rating",multiple="stack")
plt.title('Distribution of Top 10 Movies',fontsize=15)
plt.xlabel('Year',fontsize=13)
plt.ylabel('Rating',fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Nishita\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
genre_counts= data['Genre'].value_counts().reset_index()
genre_counts.columns=['Genre','Count']
top_n_genres = genre_counts.head(5)
top_n_genres
# Out:
#                   Genre  Count
# 0                 Drama   1137
# 1        Drama, Romance    443
# 2  Action, Crime, Drama    417
# 3                Action    391
# 4         Drama, Family    291

# %%
plt.figure(figsize=(4,4))
plt.pie(top_n_genres['Count'],labels=top_n_genres['Genre'],autopct='%1.1f%%',startangle=140,colors=sns.color_palette('pastel'))
plt.title('Movie Genre Distribution',fontsize=12)
plt.axis('equal')
plt.show()

# %%
director_avg_rating = data.groupby('Director')['Rating'].mean().reset_index()
director_avg_rating = director_avg_rating.sort_values(by='Rating',ascending=False)
top_directors = director_avg_rating.head(10)
top_directors
# Out:
#              Director  Rating
# 2243  Saif Ali Sayeed    10.0
# 2560      Sriram Raja     9.7
# 504       Bobby Kumar     9.6
# 322     Arvind Pratap     9.4
# 1513     Munni Pankaj     9.4
# 2598   Suhrud Godbole     9.4
# 1601     Nikhil Mahar     9.3
# 2809     Venkatesh Bk     9.3
# 1879    Rahul Mallick     9.3
# 1864   Raghav Jairath     9.3

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=top_directors,x='Rating',y='Director',palette='viridis')

plt.title('Top Directors by Average Rating',fontsize=30)
plt.xlabel('Average Rating',fontsize=14)
plt.ylabel('Director',fontsize = 14)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=data,x='Rating',y='Votes')

plt.title('Votes vs. Rating',fontsize=30)
plt.xlabel('rating',fontsize=25)
plt.ylabel('Votes',fontsize=30)

plt.show()
# Out:
# C:\Users\Nishita\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Nishita\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Encoding Categorical Data

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

trans_data = data.drop(['Name'],axis=1)
trans_data['Director'] = labelencoder.fit_transform(data['Director'])
trans_data['Actor 1'] = labelencoder.fit_transform(data['Actor 1'])
trans_data['Actor 2'] = labelencoder.fit_transform(data['Actor 2'])
trans_data['Actor 3'] = labelencoder.fit_transform(data['Actor 3'])
trans_data['Genre']=labelencoder.fit_transform(data['Genre'].apply(lambda x: ', '.join(x)))
trans_data.head()
# Out:
#    Year Duration  Genre  Rating  Votes  Director  Actor 1  Actor 2  Actor 3
# 1 -2019     109     252     7.0      8       755     1686     2725      373
# 3 -2019     110     205     4.4     35      1637     1500      865     2543
# 5 -1997     147     175     4.7    827      1881      481       84     2422
# 6 -2005     142     315     7.4   1086      2486      878     1346     2996
# 8 -2012      82     351     5.6    326       161     2385     1416     1189

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
sc_data=scaler.fit_transform(trans_data)
sc_df = pd.DataFrame(sc_data,columns=trans_data.columns)
sc_df.head()
# Out:
#        Year  Duration     Genre    Rating     Votes  Director   Actor 1  \
# 0  0.019231  0.293333  0.607229  0.662921  0.000005  0.255499  0.698426
# 1  0.019231  0.296667  0.493976  0.370787  0.000051  0.553976  0.621375
# 2  0.230769  0.420000  0.421687  0.404494  0.001390  0.636548  0.199254
# 3  0.153846  0.403333  0.759036  0.707865  0.001828  0.841286  0.363712
# 4  0.086538  0.203333  0.845783  0.505618  0.000543  0.054484  0.987987
#
#     Actor 2   Actor 3
# 0  0.979511  0.123102
# 1  0.310927  0.839274
# 2  0.030194  0.799340
# 3  0.483825  0.988779
# 4  0.508986  0.392409

# %% [markdown]
# ## Split the Data into training and testing data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
x = trans_data.drop(['Rating'],axis=1)

# %%
y = trans_data['Rating']

# %% [markdown]
# ## Train the Model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
model= LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test =  np.array(x_test)

# %% [markdown]
# ## Evaluate the Model

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# C:\Users\Nishita\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6.38173569, 6.27438422, 6.24148256, ..., 5.6990634 , 6.25823896,
#        6.09526622])

# %%
print('Mean squared error: ',mean_squared_error(y_test,y_pred))
print('Mean absolute errot : ',mean_absolute_error(y_test,y_pred))
# Out:
# Mean squared error:  1.6972873264362012
# Mean absolute errot :  1.0286370452288058

# %% [markdown]
# ## Making Predictions

# %%
print(y_test)
# Out:
# 6241     7.4
# 3321     4.9
# 6117     6.5
# 5975     5.7
# 6653     7.0
#         ...
# 14566    3.5
# 10966    5.2
# 10168    2.7
# 14796    4.9
# 2785     8.0
# Name: Rating, Length: 2268, dtype: float64
